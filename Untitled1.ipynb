# %%
import numpy as np
import pandas as pd
from matplolib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6ebc69512f73> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from matplolib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplolib'

# %%
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 20, 1000)
y = np.sin(x)
fig = plt.figure(figsize=(8,4)) 
ax = fig.add_subplot(1,1,1) # row-col-num
plp0oiiuyax.plot(x, y, 'b-', linewidth=2, label='Sample label')

# %%
x = np.linspace(0, 20, 1000)
y = np.sin(x)
fig = plt.figure(figsize=(8,4)) 
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(x, y, 'b-', linewidth=2, label='Sample label')

# %%
x=np.arange(0,409305)
y=np.arange(0,219212)
plt.bar(x,y,color='red')

# %%
from matplotlib import pyplot as plt
ax=plt.subplots()
(a,b,c)=plt.subplots(nrows=4,ncols=3,figsize=(8,4),sharex='true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6694ed3a9f88> in <module>
#       1 from matplotlib import pyplot as plt
#       2 ax=plt.subplots()
# ----> 3 (a,b,c)=plt.subplots(nrows=4,ncols=3,figsize=(8,4),sharex='true')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1218     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1219                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1220                        gridspec_kw=gridspec_kw)
#    1221     return fig, axs
#    1222
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1500
#    1501             raise ValueError("sharex [%s] must be one of %s" %
# ...

# %%
fig, ax = plt.subplots()
fig,(ax1,ax2,ax3) = plt.subplots(nrows=3, ncols=1, sharex=True,
figsize=(8,4))
# Iterating the Axes within a Figure
for ax in fig.get_axes():
    pass

# %%
import numpy as np
x = np.linspace(0, 20, 1000)
y = np.sin(x)
fig = plt.figure(figsize=(8,4)) # get an empty figure and add an Axes
ax = fig.add_subplot(1,1,1) # row-col-num
ax.plot(x, y, 'b-', linewidth=2, label='Sample label') # line plot data onthe Axes
# add title, labels and legend, etc.
ax.set_ylabel('y axis label', fontsize=16) # y label
ax.set_xlabel('x axis lable', fontsize=16)
ax.legend(loc='best')
fig.tight_layout(pad=5)

# %%
x1 = np.linspace(0, 100, 20)
x2 = np.linspace(0, 100, 20)
x3 = np.linspace(0, 100, 20)
y1 = np.sin(x1)
y2 = np.cos(x2)
y3 = np.tan(x3)
plt.plot(x1, y1, label='sin')
plt.plot(x2, y2, label='cos')
plt.plot(x3, y3, label='tan')
# add grid, legend, title and save
ax.grid(True)
ax.legend(loc='best', prop={'size':'large'})
fig.suptitle('A Simple Multi Axis Line Plot')
plt.plot(x1,y1,x2,y2,x3,y3)
